# %% [markdown]
# # Load Time Lapse (Lapse It iOS App) Images and Compare Colors over time
#
# 220902 AFRG v1.0 <br>
# 220904 AFRG v1.1 <br>
# 220904 RG v1.2 Minor user mod <br>
#
# This version of notebook has some test code - that will not appear in main version

# %% [markdown]
# ## Setup including interactive render environment

# %% [markdown]
# matplotlib.use() supported values are ['GTK3Agg', 'GTK3Cairo', 'GTK4Agg', 'GTK4Cairo', 'MacOSX', 'nbAgg', 'QtAgg', 'QtCairo', 'Qt5Agg', 'Qt5Cairo', 'TkAgg', 'TkCairo', 'WebAgg', 'WX', 'WXAgg', 'WXCairo', 'agg', 'cairo', 'pdf', 'pgf', 'ps', 'svg', 'template']

# %%
import matplotlib
# Want interactive plot
# matplotlib.use('Qt5Agg') # Error - need additional install?
#matplotlib.use('module://backend_interagg') # ModuleNotFoundError: No module named 'backend_interagg'
matplotlib.use('QtAgg')
# matplotlib.use('Qt6') # Shows list of backends
# matplotlib.use('MacOSX') # No figure appears inline
import matplotlib.pyplot as plt
import matplotlib.widgets as widgets

from PIL import Image,ImageOps   # https://pillow.readthedocs.io/en/stable/installation.html
import numpy as np

# from packaging import version
# version.parse(Image.PILLOW_VERSION)    # https://stackoverflow.com/questions/24688802/saving-an-animated-gif-in-pillow

# Which machine are you running on
#import socket
#socket.gethostname()

# Which user - use for iCloud mount
username = os.environ.get( "USER" ) # Looking for gaitskel or Araminta
print( username )
# Out:
# gaitskel

# %% [markdown]
# ## Load dataset - select manually

# %%
if 1: # Local storage in project directory
    path = '/Users/'+username+'/Library/Mobile Documents/com~apple~CloudDocs/'
    # dataFolder = '20220904_110525/' # Two Apples as a basic test - moved a little
    # dataFolder = '20220904_151732/' # 3 Apples - 2 Red, 1 G - no surface treatment
    #dataFolder = '20220904_191032/' # 3 Apples - Citric Acid #1 most concentrated 10 g 10ml, x1/5, x1/5 #3 least
    dataFolder = '20220904_204042/' # 3 Apples - (1) Water shaken off, (2) (3) 1g Citric, 300 ml water added 2.5 ml
    dataFolderType = ''
    dataType = 'jpg'

if 0: # Local storage in project directory
    path = 'data/'
    dataFolder = '20220903_205057/'
    dataFolderType = 'jpg/'
    dataType = 'jpg'

if 0: # Store Lapse It as a movie
    file = 'exported_2022-09-03_19-39-54.mp4'

# %% [markdown]
# ### List available files

# %%
# List all files in a directory
import os
# imageList = sorted(os.listdir( path + dataFolder + dataFolderType))
imageList = np.array( sorted(os.listdir( path + dataFolder )) )
imageList = imageList[ [ ".jpg" in x  for x in imageList]  ]
imageList
# Out:
# array(['20220904_204142[2].jpg', '20220904_204242[3].jpg',
#        '20220904_204342[4].jpg', '20220904_204442[5].jpg',
#        '20220904_204542[6].jpg', '20220904_204642[7].jpg',
#        '20220904_204742[8].jpg', '20220904_204842[9].jpg',
#        '20220904_204942[10].jpg', '20220904_205042[11].jpg',
#        '20220904_205142[12].jpg', '20220904_205242[13].jpg',
#        '20220904_205342[14].jpg', '20220904_205442[15].jpg',
#        '20220904_205542[16].jpg', '20220904_205642[17].jpg',
#        '20220904_205742[18].jpg', '20220904_205842[19].jpg',
#        '20220904_205942[20].jpg', '20220904_210042[21].jpg',
#        '20220904_210142[22].jpg', '20220904_210242[23].jpg',
#        '20220904_210342[24].jpg', '20220904_210442[25].jpg',
#        '20220904_210542[26].jpg', '20220904_210642[27].jpg',
#        '20220904_210742[28].jpg', '20220904_210842[29].jpg',
#        '20220904_210942[30].jpg', '20220904_211042[31].jpg',
#        '20220904_211142[32].jpg', '20220904_211242[33].jpg',
#        '20220904_211342[34].jpg', '20220904_211442[35].jpg',
#        '20220904_211542[36].jpg', '20220904_211642[37].jpg',
#        '20220904_211742[38].jpg', '20220904_211842[39].jpg',
#        '20220904_211942[40].jpg', '20220904_212042[41].jpg',
#        '20220904_212142[42].jpg', '20220904_212242[43].jpg',
#        '20220904_212342[44].jpg', '20220904_212442[45].jpg',
#        '20220904_212542[46].jpg', '20220904_212642[47].jpg',
#        '20220904_212742[48].jpg', '20220904_212842[49].jpg',
#        '20220904_212942[50].jpg', '20220904_213042[51].jpg',
#        '20220904_213142[52].jpg', '20220904_213242[53].jpg',
#        '20220904_213343[54].jpg', '20220904_213443[55].jpg',
#        '20220904_213543[56].jpg', '20220904_213643[57].jpg',
#        '20220904_213743[58].jpg', '20220904_213843[59].jpg',
#        '20220904_213943[60].jpg', '20220904_214043[61].jpg',
#        '20220904_214143[62].jpg', '20220904_214243[63].jpg',
#        '20220904_214343[64].jpg', '20220904_214443[65].jpg',
#        '20220904_214543[66].jpg', '20220904_214643[67].jpg',
#        '20220904_214743[68].jpg', '20220904_214843[69].jpg',
#        '20220904_214943[70].jpg', '20220904_215043[71].jpg',
#        '20220904_215143[72].jpg', '20220904_215243[73].jpg',
#        '20220904_215343[74].jpg', '20220904_215443[75].jpg',
#        '20220904_215543[76].jpg', '20220904_215643[77].jpg',
#        '20220904_215743[78].jpg', '20220904_215843[79].jpg',
#        '20220904_215943[80].jpg', '20220904_224043[121].jpg',
#        '20220904_224143[122].jpg', '20220904_224243[123].jpg',
#        '20220904_224343[124].jpg', '20220904_224443[125].jpg',
#        '20220904_224543[126].jpg', '20220904_224643[127].jpg',
#        '20220904_224743[128].jpg', '20220904_224843[129].jpg',
#        '20220904_224943[130].jpg', '20220904_225043[131].jpg'],
#       dtype='<U49')

# %% [markdown]
# ## Set Zoom Range Manually

# %%
### Define Region of Image to Monitor - Manually
with Image.open(path + dataFolder + dataFolderType + imageList[0]) as im:
    width, height = im.size
    print((width, height))

# Setting the points for cropped image
if 1:
    left = height * 0
    right = width * 1
    top = height * 0
    bottom = height * 1
if 0:  # Manual select of ROI
    left = width * 3 / 16
    right = width * 13 / 32
    top = height * 5 / 16
    bottom = height * 9 / 16
# Out:
# (1280, 720)

# %% [markdown]
# ## Show First and Last Images

# %%
# https://pillow.readthedocs.io/en/stable/reference/Image.html

# Cropped image of above dimension
# (It will not change original image)
# im1 = im.crop((left, top, right, bottom))

for ii in [ imageList[0],imageList[-1]]:
# for ii in imageList[0:5]:
    with Image.open( path + dataFolder + dataFolderType + ii ) as im:
        # im.show() # image appears in MacOS App Preview
        # im.rotate(-90)
        display( im.crop((left, top, right, bottom)) )
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>
# <PIL.Image.Image image mode=RGB size=1280x720>

# %% [markdown]
# ## Save GIFs that show animation

# %%
# Save files as individual gifs - not using this
if 0:
    for imageName in imageList[0:2]:
        with Image.open( path + dataFolder + dataFolderType + imageName ) as im:
            im.crop((left, top, right, bottom)).save( path + dataFolder + imageName[:-4]+'.gif' )

# %%
# Save all files in a single animated gif
if 1:
    out = []
    for imageName in imageList:
        with Image.open( path + dataFolder + dataFolderType + imageName ) as im:
            out.append( im.crop((left, top, right, bottom)) )

    (out[0]).save( path + dataFolder + "animated_all.gif"
                   , save_all = True
                   , append_images = out[1:]
                   , duration = 100
                   , loop = 0
                   )

# %%
# Save first and last files in a single animated gif

if 1:
    (out[0]).save( path + dataFolder + "animated_first_and_last.gif"
               , save_all = True
               , append_images = out[-1:]
               , duration = 100
               , loop = 0
               )

# %% [markdown]
# ## MaKE A GRAYSCALE image

# %%
if 0:
    imgray = ImageOps.grayscale( im ) # https://appdividend.com/2020/06/22/how-to-convert-pil-image-to-grayscale-in-python/
    a = np.asarray( imgray )
    a.shape
    display( imgray.rotate(-90) )

# %% [markdown]
# ## Select Region

# %%
def onselect(eclick, erelease):
    if eclick.ydata>erelease.ydata:
        eclick.ydata,erelease.ydata = erelease.ydata,eclick.ydata
    if eclick.xdata>erelease.xdata:
        eclick.xdata,erelease.xdata = erelease.xdata,eclick.xdata
    ax.set_ylim(erelease.ydata,eclick.ydata)
    ax.set_xlim(eclick.xdata,erelease.xdata)
    fig.canvas.draw()

# %%
# Crop image using mouse drag of rectangle
fig = plt.figure()
ax = fig.add_subplot(111)
# filename="test.png"
filename = path + dataFolder + dataFolderType + imageList[0]
im = Image.open(filename)
arr = np.asarray(im)
plt_image = plt.imshow(arr)
# matplotlib.use('QtAgg') - works
rs = widgets.RectangleSelector(
    ax
    , onselect=onselect
    , props = dict(facecolor='red', edgecolor = 'black', alpha=0.5, fill=True)
    # , drawtype='box'
    )
    # rectprops = dict(facecolor='red', edgecolor = 'black', alpha=0.5, fill=True))
plt.show()

print('Rectangle')
print([ [ f'{x:.0f}' for x in y ] for y in rs.corners ])
# Out:
# Rectangle
# [['521', '614', '614', '521'], ['217', '217', '258', '258']]

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

# Define image from dragged rectangle in previous image
left = np.min(rs.corners[0])
right = np.max(rs.corners[0])
top = np.min(rs.corners[1])
bottom = np.max(rs.corners[1])
print( (left,top,right,bottom) )

# Show image based on crop
arr = np.asarray(im.crop((left,top,right,bottom)))
plt_image = plt.imshow(arr)
plt.show(  )
# Out:
# (520.7903225806451, 216.5322580645161, 613.6935483870968, 257.8225806451612)

# %%
if 1:
    target = "RD#1 Control" # Most of apple
    (left,top,right,bottom) = (110.4677419354839, 221.6935483870967, 332.40322580645164, 567.5)

if 1:
    target = "G#1 Control" # Most of apple
    (left,top,right,bottom) = (840.7903225806451, 239.75806451612902, 1109.1774193548385, 572.6612903225806)

if 1:
    target = "Paper Control" # Lower paper
    (left,top,right,bottom) = (365.9516129032258, 593.3064516129032, 505.30645161290323, 706.8548387096773)

if 1:
    target = "RD#2 Citric x3" # Lower paper
    (left,top,right,bottom) = (840.7903225806451, 410.08064516129025, 1083.3709677419354, 559.758064516129)

if 1:
    target = "RD#3 Water or Citric" # Lower paper
    (left,top,right,bottom) = (30.467741935483872, 301.6935483870967, 162.0806451612903, 510.7258064516128)

# %%
arr.shape
# Out:
# (346, 222, 3)

# %%
display( im.crop((left,top,right,bottom)) )
# Out:
# <PIL.Image.Image image mode=RGB size=242x150>

# %%
arr.shape
# Out:
# (114, 139, 3)

# %% [markdown]
# ## Try measuring the color of the segment of Apple images

# %%
plt.imshow( arr )
plt.show(  )

# %%
imageList
# Out:
# array(['20220904_151733[1].jpg', '20220904_151833[2].jpg',
#        '20220904_151933[3].jpg', '20220904_152033[4].jpg'], dtype='<U22')

# %%
rgb_mean = []

for ii,iim in enumerate( imageList[::1] ):
    with Image.open( path + dataFolder + dataFolderType + iim ) as im:
        # im.show() # image appears in MacOS App Preview
        # im.rotate(-90)


        if 0: # Original Full Image
            imc = im
            display( imc )
        else: # Cropped Image
            imc = im.crop((left, top, right,bottom))

        arr = np.asarray(imc)
        # print( f"Image :{ii}")
        rgb_mean.append(
            [ii, np.mean(arr[:,:,0]),np.mean(arr[:,:,1]),np.mean(arr[:,:,2])]
        )
        print(
           f"Image :{ii} Red:{np.mean(arr[:,:,0]):.2f}, Blue:{np.mean(arr[:,:,1]):.2f}, Green:{np.mean(arr[:,:,2]):.2f}"
        )

        if 0:
            if 1:
                display( imc )
            else: # Blow up the cropped image to see it better
                width,height = imc.size
                display(
                    imc.resize( (width,height) )  # .resize((new_img_width, new_img_height))
                )


        # width, height = im.size
        #display(
        #    imc.resize((width,height))
        #)

rgb_mean = np.array( rgb_mean ) # , dtype=object )
# Out:
# Image :0 Red:208.72, Blue:198.67, Green:111.47
# Image :1 Red:208.63, Blue:198.89, Green:110.79
# Image :2 Red:208.72, Blue:198.52, Green:109.86
# Image :3 Red:208.88, Blue:198.17, Green:109.22
# Image :4 Red:208.92, Blue:197.88, Green:108.49
# Image :5 Red:208.94, Blue:197.51, Green:107.84
# Image :6 Red:208.89, Blue:197.13, Green:107.31
# Image :7 Red:208.61, Blue:196.75, Green:106.51
# Image :8 Red:208.48, Blue:196.29, Green:105.88
# Image :9 Red:208.74, Blue:196.20, Green:105.66
# Image :10 Red:208.56, Blue:195.95, Green:105.24
# Image :11 Red:208.63, Blue:195.78, Green:104.89
# Image :12 Red:208.52, Blue:195.46, Green:104.41
# Image :13 Red:208.46, Blue:195.35, Green:104.06
# Image :14 Red:208.43, Blue:195.10, Green:103.63
# Image :15 Red:208.55, Blue:194.97, Green:103.31
# Image :16 Red:208.40, Blue:194.79, Green:103.05
# Image :17 Red:208.30, Blue:194.57, Green:102.56
# Image :18 Red:208.36, Blue:194.43, Green:102.38
# Image :19 Red:208.30, Blue:194.24, Green:102.01
# Image :20 Red:208.18, Blue:194.11, Green:101.84
# Image :21 Red:208.10, Blue:194.04, Green:101.44
# Image :22 Red:208.21, Blue:193.89, Green:101.19
# Image :23 Red:208.08, Blue:193.79, Green:101.06
# Image :24 Red:208.16, Blue:193.73, Green:100.78
# Image :25 Red:208.16, Blue:193.54, Green:100.64
# Image :26 Red:208.17, Blue:193.56, Green:100.35
# Image :27 Red:208.17, Blue:193.42, Green:100.29
# Image :28 Red:208.15, Blue:193.33, Green:100.04
# Image :29 Red:208.18, Blue:193.24, Green:99.84
# Image :30 Red:208.17, Blue:193.17, Green:99.71
# Image :31 Red:208.09, Blue:193.03, Green:99.51
# Image :32 Red:208.15, Blue:193.03, Green:99.51
# Image :33 Red:208.08, Blue:192.91, Green:99.39
# Image :34 Red:208.01, Blue:192.95, Green:99.12
# Image :35 Red:208.13, Blue:192.84, Green:99.03
# Image :36 Red:208.20, Blue:192.83, Green:98.90
# Image :37 Red:208.16, Blue:192.78, Green:98.91
# Image :38 Red:208.10, Blue:192.72, Green:98.77
# Image :39 Red:208.17, Blue:192.73, Green:98.61
# Image :40 Red:208.14, Blue:192.66, Green:98.46
# Image :41 Red:208.21, Blue:192.63, Green:98.34
# Image :42 Red:208.22, Blue:192.58, Green:98.30
# Image :43 Red:208.09, Blue:192.47, Green:98.10
# Image :44 Red:208.24, Blue:192.39, Green:98.04
# Image :45 Red:208.13, Blue:192.36, Green:97.91
# Image :46 Red:208.02, Blue:192.30, Green:97.66
# Image :47 Red:208.03, Blue:192.28, Green:97.68
# Image :48 Red:208.09, Blue:192.23, Green:97.59
# Image :49 Red:208.16, Blue:192.20, Green:97.55
# Image :50 Red:208.05, Blue:192.09, Green:97.42
# Image :51 Red:207.98, Blue:192.05, Green:97.28
# Image :52 Red:207.99, Blue:192.01, Green:97.32
# Image :53 Red:208.04, Blue:191.95, Green:97.12
# Image :54 Red:208.03, Blue:192.00, Green:96.96
# Image :55 Red:208.16, Blue:191.95, Green:97.02
# Image :56 Red:208.03, Blue:191.88, Green:96.92
# Image :57 Red:208.01, Blue:191.85, Green:96.87
# Image :58 Red:208.09, Blue:191.81, Green:96.81
# Image :59 Red:208.04, Blue:191.77, Green:96.71
# Image :60 Red:208.03, Blue:191.79, Green:96.67
# Image :61 Red:207.98, Blue:191.72, Green:96.53
# Image :62 Red:208.17, Blue:191.68, Green:96.52
# Image :63 Red:207.97, Blue:191.67, Green:96.33
# Image :64 Red:208.07, Blue:191.62, Green:96.29
# Image :65 Red:208.08, Blue:191.64, Green:96.13
# Image :66 Red:207.99, Blue:191.63, Green:96.08
# Image :67 Red:208.09, Blue:191.55, Green:96.14
# Image :68 Red:208.05, Blue:191.52, Green:96.18
# Image :69 Red:208.15, Blue:191.61, Green:96.22
# Image :70 Red:208.08, Blue:191.54, Green:96.02
# Image :71 Red:208.11, Blue:191.58, Green:95.96
# Image :72 Red:208.18, Blue:191.57, Green:95.97
# Image :73 Red:208.22, Blue:191.64, Green:95.87
# Image :74 Red:208.13, Blue:191.59, Green:95.91
# Image :75 Red:208.15, Blue:191.56, Green:95.66
# Image :76 Red:208.26, Blue:191.55, Green:95.82
# Image :77 Red:208.14, Blue:191.55, Green:95.67
# Image :78 Red:208.17, Blue:191.51, Green:95.67
# Image :79 Red:208.20, Blue:191.49, Green:95.57
# Image :80 Red:208.13, Blue:191.53, Green:95.51
# Image :81 Red:208.20, Blue:191.48, Green:95.59
# Image :82 Red:204.74, Blue:192.64, Green:98.84
# Image :83 Red:204.79, Blue:192.72, Green:98.77
# Image :84 Red:204.86, Blue:192.67, Green:98.91
# Image :85 Red:204.80, Blue:192.59, Green:98.69
# Image :86 Red:204.79, Blue:192.59, Green:98.59
# Image :87 Red:204.74, Blue:192.55, Green:98.51
# Image :88 Red:204.72, Blue:192.54, Green:98.43
# Image :89 Red:204.89, Blue:192.61, Green:98.51
# Image :90 Red:204.78, Blue:192.52, Green:98.30
# Image :91 Red:204.73, Blue:192.50, Green:98.37
# Image :92 Red:204.71, Blue:192.44, Green:98.31
# Image :93 Red:204.71, Blue:192.46, Green:98.25
# Image :94 Red:204.71, Blue:192.48, Green:98.16
# Image :95 Red:204.79, Blue:192.46, Green:98.21
# Image :96 Red:204.58, Blue:192.36, Green:98.08
# Image :97 Red:204.62, Blue:192.40, Green:97.90
# Image :98 Red:204.63, Blue:192.38, Green:98.03
# Image :99 Red:204.73, Blue:192.43, Green:97.99
# Image :100 Red:204.71, Blue:192.41, Green:97.88
# Image :101 Red:204.72, Blue:192.41, Green:97.99
# Image :102 Red:204.70, Blue:192.41, Green:97.76
# Image :103 Red:204.64, Blue:192.33, Green:97.90
# Image :104 Red:204.69, Blue:192.28, Green:97.83
# Image :105 Red:204.69, Blue:192.35, Green:97.83
# Image :106 Red:204.71, Blue:192.32, Green:97.78
# Image :107 Red:204.72, Blue:192.31, Green:97.69
# Image :108 Red:204.63, Blue:192.23, Green:97.71

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot( rgb_mean[:,0] , rgb_mean[:,1]/2.55 , 'r-' , label='Red')
ax.plot( rgb_mean[:,0] , rgb_mean[:,2]/2.55 , 'g-' , label='Green')
ax.plot( rgb_mean[:,0] , rgb_mean[:,3]/2.55 , 'b-' , label='Blue')
ax.legend()
ax.set_xlabel('Time [mins]')
ax.set_ylabel('Color % [Higher is Brighter]')
ax.grid( True )
plt.title( imageList[0][:-4]+" "+target )
plt.savefig(  path + dataFolder + dataFolderType + imageList[0][:-4]+" "+target+"_RGB.png" )
plt.show( )

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

ax.plot( rgb_mean[:,0]
         , (rgb_mean[:,1]+rgb_mean[:,2]+rgb_mean[:,3])/(3.*2.55)
         , 'k-' , label='White')
ax.legend()
ax.set_xlabel('Time [mins]')
ax.set_ylabel('Wite % [Higher is Brighter]')
ax.grid( True )

plt.title( imageList[0][:-4]+" "+target )
plt.savefig(  path + dataFolder + dataFolderType + imageList[0][:-4]+" "+target+"_White.png" )
plt.show( )

# %% [markdown]
# # Demo Drawing A White Rectangle

# %%
(left, top, right, bottom) = (110, 222, 332, 568)

img = Image.open(path + dataFolder + dataFolderType + imageList[0])  # .crop((left, top, right, bottom))
img = img.convert("RGBA")

if 0:
    # This works
    overlay = Image.new('RGBA', img.size, (255, 255, 255, 0))
    draw = ImageDraw.Draw(overlay)
    draw.rectangle(((left, top), (right, bottom)))  # White edge,   ((llx, lly), (urx, ury))   ((50, 100), (200, 300))
    # img.size[0],img.size[1] , fill=(255,0,0,50)
    # Alpha composite these two images together to obtain the desired result.
    img = Image.alpha_composite(img, overlay)
else:
    # This works
    draw = ImageDraw.Draw(img, "RGBA")
    draw.rectangle(((left, top), (right, bottom)))  # White edge,   ((llx, lly), (urx, ury))   ((50, 100), (200, 300))

img = img.convert("RGB")  # Remove alpha for displaying

display(img)
